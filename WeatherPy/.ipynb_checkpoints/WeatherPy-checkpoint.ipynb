# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#DO NOT RUN THIS CELL
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# Import API key
from config import weathapi_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#DO NOT RUN THIS CELL
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
#DO NOT RUN THIS ANYMORE!!!!!!!

# %%
# Print the city count to confirm sufficient count
len(cities)
#cities
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
#city = 'beba'

# Build partial query URL
query_url = f"{url}appid={weathapi_key}&units={units}&q="
query_url

# %%
# set up lists to hold response info
cit = []
lat = []
lng = []
temp = []
humid = []
MaxT = []
cloud = []
wind = []
country = []
date = []

# Get weather data
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# Get the temperature from the response
#pprint(weather_json)
for city1 in cities:
    try:
        response = requests.get(query_url + city1).json()
        temp_lat = response['coord']['lat']
        temp_lng = response['coord']['lon']
        temp_temp = response['main']['temp']
        temp_humid = response['main']['humidity']
        temp_MaxT = response['main']['temp_max']
        temp_cloud = response['clouds']['all']
        temp_wind = response['wind']['speed']
        temp_country = response['sys']['country']
        temp_date = response['dt']
        temp_cit = response['name']
        lat.append(temp_lat)
        lng.append(temp_lng)
        temp.append(temp_temp) 
        humid.append(temp_humid)
        MaxT.append(temp_MaxT)
        cloud.append(temp_cloud)
        wind.append(temp_wind)
        country.append(temp_country)
        date.append(temp_date)
        cit.append(temp_cit)
        print(f"The temperature for {city1} is {response['main']['temp']}")
    except:
        print(f"No information available for {city1}")
# Out:
# The temperature for savelugu is 74.59
# The temperature for svetlogorsk is 65.98
# The temperature for pevek is 37.65
# The temperature for borshchiv is 64
# The temperature for mehamn is 53.6
# The temperature for la ronge is 51.8
# The temperature for hithadhoo is 82.02
# The temperature for busselton is 48.22
# The temperature for kiunga is 71.51
# The temperature for kununurra is 68
# The temperature for chernyshevskiy is 42.62
# The temperature for nanortalik is 47.14
# The temperature for faanui is 75.81
# No information available for kazalinsk
# The temperature for pisco is 64.24
# The temperature for ribeira grande is 77
# The temperature for upernavik is 42.06
# No information available for bolungarvik
# The temperature for bluff is 45
# No information available for vaitupu
# The temperature for atuona is 77.95
# The temperature for college is 51.3
# The temperature for kapaa is 71.17
# The temperature for uruzgan is 79.65
# The temperature for east london is 69.8
# The temperature for mataura is 45
# The temperature for rikitea is 69.37
# The temperature for nantucket is 77
# The temperature for waipawa is 45
# The temperature for albany is 79.27
# The temperature for naze is 82.4
# No information available for belushya guba
# The temperature for khatanga is 57.51
# The temperature for jamestown is 75.33
# The temperature for ushuaia is 41
# The temperature for bandarbeyla is 77.32
# No information available for sataua
# The temperature for hermanus is 62.01
# The temperature for eureka is 55.69
# The temperature for north platte is 80.71
# The temperature for bambous virieux is 71.78
# The temperature for victoria is 85.03
# The temperature for punta arenas is 37.2
# The temperature for hobart is 47.91
# The temperature for qaanaaq is 36.81
# No information available for illoqqortoormiut
# The temperature for saint-philippe is 66.54
# The temperature for airai is 53.33
# The temperature for verkhoyansk is 36.37
# The temperature for half moon bay is 62.29
# The temperature for saskylakh is 54.59
# The temperature for kloulklubed is 77
# No information available for bathsheba
# No information available for armacao dos buzios
# The temperature for batagay is 33.62
# The temperature for hervey bay is 51.71
# The temperature for avera is 78.87
# No information available for tsihombe
# The temperature for nikolskoye is 65.37
# No information available for taolanaro
# The temperature for norden is 62.17
# The temperature for cape canaveral is 88.83
# The temperature for kavaratti is 81.66
# The temperature for port elizabeth is 62.6
# The temperature for sitka is 53.6
# The temperature for cape town is 61.61
# The temperature for nelas is 86.81
# The temperature for alofi is 69.8
# The temperature for vila franca do campo is 77
# The temperature for ponta do sol is 76.77
# The temperature for norman wells is 53.6
# No information available for lolua
# The temperature for matane is 64
# The temperature for gat is 83.25
# The temperature for koslan is 57.63
# The temperature for mar del plata is 55.4
# The temperature for esperance is 51.8
# The temperature for kabansk is 53.6
# The temperature for tuktoyaktuk is 44.6
# The temperature for dahuk is 86.59
# The temperature for tevriz is 53.19
# The temperature for castro is 62.67
# The temperature for broken hill is 44.6
# The temperature for avarua is 71.6
# The temperature for kakonko is 75.99
# The temperature for chokurdakh is 37.29
# The temperature for khartoum is 94.44
# The temperature for puerto escondido is 75.2
# The temperature for verkhniy baskunchak is 76.71
# No information available for barentsburg
# The temperature for port alfred is 65.84
# The temperature for yulara is 69.8
# The temperature for zhengjiatun is 71.04
# The temperature for mnogovershinnyy is 51.44
# The temperature for new norfolk is 45.57
# The temperature for kodiak is 50
# The temperature for chuy is 64.76
# The temperature for kurya is 54.55
# The temperature for zilair is 58.86
# The temperature for aleksandriyskaya is 77
# No information available for sumbawa
# The temperature for zorgo is 79.65
# The temperature for mogadishu is 77.52
# The temperature for rawson is 48.04
# The temperature for saint george is 84.81
# The temperature for west wendover is 77
# The temperature for corrales is 77.63
# The temperature for bonavista is 63
# The temperature for stepnyak is 58.82
# The temperature for hovd is 64.38
# The temperature for butaritari is 81.88
# The temperature for vaini is 66.2
# The temperature for ashland is 81.68
# The temperature for husavik is 51.8
# The temperature for tessaoua is 90.19
# The temperature for tiksi is 37.69
# The temperature for miri is 84.11
# The temperature for ajnala is 82.4
# The temperature for vila velha is 73.08
# The temperature for clyde river is 43.25
# No information available for burica
# The temperature for henties bay is 55.99
# The temperature for hachinohe is 72.66
# The temperature for ambilobe is 73.62
# No information available for palabuhanratu
# The temperature for qaqortoq is 51.8
# The temperature for buala is 80.06
# The temperature for kirakira is 79.25
# The temperature for lagunillas is 86.72
# The temperature for urucara is 94.8
# The temperature for najran is 100.4
# The temperature for narsaq is 51.8
# No information available for nizhneyansk
# The temperature for ola is 46.8
# The temperature for tiznit is 102.88
# The temperature for inhambane is 75.24
# The temperature for cayenne is 84.2
# The temperature for sidney is 44.94
# The temperature for lompoc is 61.93
# The temperature for mahanoro is 69.67
# The temperature for mariinsk is 55.94
# The temperature for biak is 75.99
# No information available for kamenskoye
# The temperature for palauig is 82.69
# The temperature for pacific grove is 58.84
# The temperature for buta is 80.47
# The temperature for glossa is 82.4
# The temperature for haines junction is 49.5
# The temperature for manakara is 70.29
# The temperature for katherine is 73.4
# The temperature for lufilufi is 73.4
# The temperature for touros is 86
# The temperature for cartagena del chaira is 86.41
# The temperature for powell is 84.45
# The temperature for mama is 49.17
# The temperature for maneadero is 73
# The temperature for puerto ayora is 69.96
# The temperature for thompson is 50
# The temperature for torbay is 60.55
# The temperature for el nispero is 80.89
# The temperature for pitimbu is 84.2
# No information available for sentyabrskiy
# The temperature for guerrero negro is 77.56
# The temperature for cabo san lucas is 86.61
# The temperature for provideniya is 48.18
# The temperature for novyy nekouz is 63.84
# No information available for saleaula
# The temperature for klaksvik is 48.2
# The temperature for vikhorevka is 53.29
# The temperature for hilo is 65.93
# The temperature for pombas is 87.8
# The temperature for ventersburg is 67.66
# The temperature for ponferrada is 88.2
# The temperature for zgorzelec is 71.01
# The temperature for jinka is 70.56
# No information available for dranceni sat
# The temperature for bredasdorp is 62.6
# The temperature for ketchikan is 54.32
# The temperature for fujinomiya is 73.4
# The temperature for gamba is 76.91
# The temperature for cidreira is 65.41
# The temperature for maniitsoq is 46.8
# The temperature for hofn is 50.67
# No information available for meyungs
# The temperature for san carlos is 85.17
# The temperature for elliot is 66.42
# The temperature for georgetown is 78.49
# The temperature for saint-francois is 86.4
# The temperature for cherskiy is 37.96
# The temperature for kokkola is 56.19
# The temperature for grand gaube is 72
# No information available for alotau
# The temperature for lahaina is 73.81
# The temperature for andapa is 65.37
# The temperature for barrow is 39.2
# The temperature for leningradskiy is 41.45
# The temperature for carnarvon is 64.4
# No information available for attawapiskat
# The temperature for griffith is 81.34
# The temperature for tabou is 78.35
# No information available for amderma
# The temperature for srednekolymsk is 37.81
# The temperature for quang ngai is 81.36
# The temperature for bambanglipuro is 75.65
# The temperature for nemuro is 64.38
# The temperature for mlonggo is 77.07
# The temperature for los llanos de aridane is 80.13
# The temperature for pangoa is 79.99
# The temperature for olinda is 82.4
# The temperature for maarianhamina is 64.4
# The temperature for greytown is 66.94
# The temperature for talnakh is 57.2
# The temperature for viransehir is 88
# The temperature for pervomayskiy is 67.69
# The temperature for tilichiki is 37.26
# The temperature for kungurtug is 50.97
# The temperature for khani is 82.4
# The temperature for ciudad guayana is 89.01
# The temperature for fuling is 73.45
# The temperature for san lawrenz is 82.85
# The temperature for lebu is 53.49
# The temperature for tasiilaq is 46.4
# The temperature for campo grande is 84.2
# The temperature for yellowknife is 53.22
# The temperature for arraial do cabo is 73.4
# The temperature for tuatapere is 45
# The temperature for vanavara is 54.16
# The temperature for porto novo is 80.35
# The temperature for ilulissat is 42.8
# The temperature for komsomolskiy is 78.8
# The temperature for oranjemund is 58.15
# The temperature for coahuayana is 73.4
# The temperature for pamfila is 87.8
# The temperature for rudnya is 69.8
# The temperature for xuddur is 82.33
# The temperature for hamilton is 86.4
# The temperature for praia da vitoria is 84.2
# The temperature for nouadhibou is 80.6
# The temperature for kemijarvi is 56.5
# No information available for tabarqah
# No information available for rungata
# The temperature for baghdad is 102.2
# The temperature for baykit is 54.99
# The temperature for nhulunbuy is 73.4
# The temperature for seoul is 82.78
# The temperature for mount gambier is 42.8
# The temperature for saint anthony is 79.52
# The temperature for dikson is 46.13
# The temperature for yangmei is 75.47
# The temperature for sumbe is 73.65
# The temperature for padang is 78.46
# The temperature for tromso is 50
# The temperature for mayo is 86.07
# The temperature for navahrudak is 60.19
# The temperature for strezhevoy is 51.8
# The temperature for yumen is 78.21
# The temperature for smolenka is 55.4
# The temperature for san patricio is 80.6
# The temperature for cimislia is 86
# The temperature for codrington is 40.37
# The temperature for santa lucia is 81.59
# The temperature for along is 76.66
# The temperature for beringovskiy is 47.82
# The temperature for kaoma is 79.61
# The temperature for severo-kurilsk is 53.08
# The temperature for frederick is 81.45
# No information available for artyk
# The temperature for mount juliet is 84.13
# The temperature for paita is 69.8
# The temperature for saldanha is 60.8
# The temperature for bud is 85.68
# No information available for aflu
# The temperature for moche is 64.54
# The temperature for calama is 55.4
# The temperature for nanning is 82.4
# The temperature for ternate is 80.01
# The temperature for rio gallegos is 39.2
# The temperature for pontes e lacerda is 101.14
# The temperature for morrope is 64.4
# The temperature for limbang is 80.29
# The temperature for port blair is 82.36
# The temperature for iqaluit is 48.09
# The temperature for liverpool is 59.95
# The temperature for aswan is 101.86
# The temperature for the valley is 86.25
# The temperature for saint-augustin is 64.99
# The temperature for itacoatiara is 96.26
# The temperature for lons-le-saunier is 83.44
# The temperature for portland is 59.02
# The temperature for gairo is 86.72
# The temperature for katangli is 54.91
# The temperature for sakakah is 104
# The temperature for kahului is 74.53
# The temperature for chandvad is 71.62
# The temperature for aklavik is 48.2
# The temperature for geraldton is 50
# The temperature for dunedin is 39.33
# The temperature for sao joao da barra is 75.2
# The temperature for kruisfontein is 62.01
# The temperature for straumen is 52.43
# The temperature for bengkulu is 78.49
# The temperature for sumenep is 79.74
# The temperature for vostok is 59.94
# The temperature for sisimiut is 48.42
# The temperature for bolshoye nagatkino is 65.19
# The temperature for ormara is 82.42
# The temperature for hukuntsi is 70.18
# The temperature for zyryanka is 36.19
# The temperature for anloga is 82.4
# The temperature for leopold is 43.93
# The temperature for dubbo is 33.8
# The temperature for peleduy is 49.53
# The temperature for chalchihuites is 64.85
# The temperature for champerico is 79.72
# The temperature for sarajevo is 70.43
# The temperature for mariakani is 78.8
# The temperature for moose factory is 53.6
# The temperature for chara is 45.3
# No information available for mys shmidta
# The temperature for condado is 87.22
# No information available for halalo
# The temperature for longyearbyen is 42.8
# The temperature for kysyl-syr is 39.87
# The temperature for makat is 80.15
# The temperature for arlit is 100.8
# The temperature for kavieng is 81.61
# The temperature for merauke is 76.87
# The temperature for eston is 63.37
# The temperature for rio casca is 73.49
# The temperature for bethel is 81.34
# The temperature for walvis bay is 57.56
# The temperature for sol-iletsk is 71.22
# The temperature for canela is 73.94
# The temperature for badajoz is 99
# The temperature for gobabis is 81.01
# The temperature for payakumbuh is 69.51
# The temperature for franklin is 85.19
# The temperature for pangnirtung is 42.8
# The temperature for tondano is 75.2
# The temperature for jacareacanga is 103.08
# The temperature for cumpas is 87.67
# The temperature for kieta is 78.26
# The temperature for berezayka is 63.79
# The temperature for belaya gora is 32.23
# The temperature for castelldefels is 84.6
# The temperature for tabuk is 75.94
# The temperature for santa vitoria do palmar is 65.35
# The temperature for pangai is 75.7
# The temperature for sarkand is 63.1
# The temperature for solnechnyy is 51.98
# The temperature for beyneu is 78.85
# The temperature for mareeba is 68
# The temperature for mackay is 51.87
# The temperature for nazilli is 91.4
# The temperature for caravelas is 74.28
# The temperature for camara de lobos is 76.8
# The temperature for maragogi is 78.53
# The temperature for zhigansk is 43.2
# The temperature for ryotsu is 73.4
# The temperature for pandan is 81.93
# The temperature for severnyy is 80.6
# The temperature for vysokogornyy is 57.88
# The temperature for tecoanapa is 80.44
# The temperature for constantine is 91.4
# The temperature for moindou is 57.2
# The temperature for ughelli is 84.18
# The temperature for satka is 59.31
# No information available for khonuu
# The temperature for la plata is 63.32
# The temperature for mecca is 98.17
# The temperature for montepuez is 78.13
# The temperature for bilibino is 39.72
# The temperature for bollnas is 68
# The temperature for catamarca is 71.42
# No information available for sorvag
# The temperature for inirida is 87.33
# The temperature for sainte-maxime is 83.21
# The temperature for soyo is 75.99
# The temperature for honiara is 75.2
# The temperature for idritsa is 63.48
# The temperature for auburn is 58.24
# The temperature for ginda is 65.77
# The temperature for vao is 67.78
# The temperature for katsuura is 77.27
# The temperature for coos bay is 54.34
# The temperature for paraiso is 71.74
# The temperature for tagusao is 80.28
# The temperature for carauari is 97.57
# No information available for samalaeulu
# The temperature for sao filipe is 79.97
# The temperature for chifeng is 68.61
# No information available for samusu
# No information available for pokanayevka
# The temperature for bardstown is 82.56
# The temperature for faya is 78.8
# The temperature for lermontovka is 64.83
# No information available for louisbourg
# The temperature for conde is 84.2
# The temperature for lorengau is 82.31
# The temperature for constitucion is 55.29
# The temperature for knysna is 59
# The temperature for san cristobal is 89.6
# The temperature for durango is 66.97
# The temperature for hasaki is 74.73
# The temperature for malanje is 80.91
# The temperature for kenai is 48.87
# The temperature for aras is 95
# The temperature for koygorodok is 58.19
# The temperature for miranda is 78.8
# The temperature for mahebourg is 71.6
# The temperature for mizdah is 89.19
# The temperature for vieques is 87.1
# The temperature for adre is 76.86
# The temperature for beloha is 69.94
# The temperature for lasa is 62.6
# The temperature for cascais is 83.88
# The temperature for souillac is 71.6
# The temperature for ponta delgada is 77
# The temperature for bonthe is 77.99
# The temperature for aykhal is 51.8
# The temperature for pemangkat is 79.41
# The temperature for ofaqim is 82
# The temperature for makurdi is 81.7
# The temperature for waterfoot is 57.16
# The temperature for lixourion is 86
# The temperature for ancud is 47.26
# The temperature for omsukchan is 31.41
# The temperature for salihorsk is 58.62
# The temperature for turan is 86
# The temperature for tessalit is 99.77
# The temperature for bangkalan is 79.48
# No information available for grand river south east
# The temperature for spirit river is 53.6
# The temperature for daru is 76.32
# No information available for ust-kamchatsk
# The temperature for salalah is 77
# The temperature for teguldet is 53.82
# The temperature for shelbyville is 83.08
# No information available for tabiauea
# The temperature for bongandanga is 81.54
# The temperature for yenagoa is 85.03
# The temperature for meulaboh is 78.15
# The temperature for korla is 85.66
# The temperature for channel-port aux basques is 64.04
# The temperature for fairbanks is 51.13
# The temperature for sompeta is 80.42
# The temperature for hambantota is 82.4
# The temperature for yarada is 80.6
# The temperature for goundam is 91.17
# No information available for sidi bu zayd
# The temperature for luderitz is 59.45
# The temperature for sheregesh is 52.39
# The temperature for tramandai is 66.02
# The temperature for itoman is 82.27
# The temperature for talcahuano is 55.4
# The temperature for port moresby is 75.2
# The temperature for comodoro rivadavia is 41
# The temperature for brookings is 75.81
# The temperature for deputatskiy is 23.74
# The temperature for okhotsk is 51.94
# The temperature for desna is 73.45
# The temperature for yarmouth is 82.74
# The temperature for zhongshu is 61.72
# The temperature for lavrentiya is 43.66
# The temperature for teseney is 85.86
# The temperature for harlingen is 82.35
# The temperature for dwarka is 82.81
# The temperature for praia is 87.8
# The temperature for san jeronimo is 61
# The temperature for jinchang is 75.99
# The temperature for castlemaine is 35.65
# The temperature for trincomalee is 82.35
# The temperature for jinxiang is 83.35
# The temperature for fortuna foothills is 94.1
# The temperature for tomatlan is 87.24
# The temperature for gazli is 74.12
# The temperature for aranos is 79.93
# The temperature for halden is 61.23
# The temperature for winnipeg is 70.9
# The temperature for santa maria del oro is 71.96
# The temperature for tautira is 71.29
# The temperature for santa cecilia is 62.87
# The temperature for gorontalo is 75.43
# The temperature for neyshabur is 67.37
# The temperature for kaitangata is 39.99
# The temperature for santa isabel do rio negro is 97.02
# The temperature for plouzane is 65.64
# The temperature for tadine is 67.01
# The temperature for bontang is 78.15
# The temperature for lagoa is 74.21
# The temperature for gustrow is 65.62
# The temperature for kontagora is 78.28
# The temperature for lata is 85.71
# The temperature for malakal is 77.9
# The temperature for semey is 61.99
# The temperature for foumban is 70.92
# The temperature for jieshi is 83.57
# The temperature for maceio is 78.8
# No information available for jiddah
# No information available for temaraia
# The temperature for quatre cocos is 71.8
# No information available for hunza
# The temperature for chernushka is 61.68
# The temperature for tura is 75.81
# The temperature for san policarpo is 80.94
# The temperature for tiarei is 71.29
# No information available for cambyreta
# No information available for guicheng
# The temperature for mitsamiouli is 78.8
# The temperature for burkburnett is 83.97
# The temperature for khanpur is 94.39
# The temperature for yar-sale is 53.87
# The temperature for zhezkazgan is 67.77
# The temperature for gunnedah is 33.8
# The temperature for ranau is 81.52
# The temperature for yerky is 79.32
# No information available for ngukurr
# The temperature for ust-kuyga is 30.51
# The temperature for george is 59
# The temperature for preobrazheniye is 69.21
# The temperature for boa vista is 86
# No information available for karaul
# The temperature for ixtapa is 79.11
# The temperature for alcains is 95.22
# The temperature for sukhoy log is 60.89
# The temperature for basco is 84.29
# The temperature for conceicao da barra is 78.01
# The temperature for touho is 69.8
# No information available for viligili
# The temperature for itaituba is 89.6
# The temperature for sao paulo de olivenca is 94.1
# The temperature for safaga is 96.8
# The temperature for bismarck is 70.11
# The temperature for moshi is 84.2
# The temperature for kouvola is 60.17
# The temperature for viedma is 48.99
# The temperature for grindavik is 51.8
# The temperature for wasilla is 50.32
# The temperature for puerto del rosario is 80.6
# The temperature for vestmannaeyjar is 53.6
# The temperature for vanimo is 77.9
# The temperature for klyuchi is 58.69
# No information available for skalistyy
# The temperature for plerin is 69.94
# The temperature for mount isa is 69.8
# The temperature for cap-aux-meules is 68
# The temperature for mbalmayo is 80.6
# No information available for satitoa
# The temperature for kingman is 89.87
# The temperature for ahuimanu is 77.34
# No information available for chaa-khol
# The temperature for san rafael is 64.51
# The temperature for broome is 76.26
# The temperature for newport is 61.77
# The temperature for sotnikovo is 53.6
# The temperature for port macquarie is 39.99
# The temperature for taoudenni is 108.77
# The temperature for gonzalez is 84.72
# The temperature for batagay-alyta is 32.68
# The temperature for vetluga is 63.45
# The temperature for upata is 89.01
# The temperature for hargeysa is 79.47
# The temperature for bereda is 82.94
# The temperature for christchurch is 38.62
# The temperature for mokhsogollokh is 38.46
# The temperature for la paz is 55.4
# The temperature for surt is 82.36
# The temperature for pirapozinho is 75.2
# The temperature for corowa is 34
# The temperature for taseyevo is 54.61
# The temperature for saint-donat-de-montcalm is 65.1
# The temperature for akdepe is 71.62
# The temperature for amapa is 93.2
# The temperature for marshall is 73.31
# The temperature for betioky is 72.64
# The temperature for richards bay is 70.52
# The temperature for ames is 85.03
# No information available for cheuskiny
# The temperature for zhizdra is 65.39
# The temperature for saint-joseph is 66.65
# The temperature for erzin is 82.99
# The temperature for antalaha is 71.74
# The temperature for okato is 44.49
# The temperature for kudahuvadhoo is 83.88
# The temperature for sattahip is 80.6
# The temperature for ballina is 51.76
# The temperature for sioux lookout is 60.8
# The temperature for pundaguitan is 83.32
# The temperature for qasigiannguit is 42.8
# The temperature for anadyr is 46.18
# The temperature for conselheiro lafaiete is 62.6
# The temperature for bardiyah is 80.91
# The temperature for pasighat is 82.27
# The temperature for matara is 79.25
# The temperature for kassala is 90.37
# The temperature for itarema is 86.65
# The temperature for teknaf is 79.5
# The temperature for saint-marc is 84.81
# The temperature for beba is 86
# The temperature for brownsville is 83.44
# The temperature for adrar is 105.91
# The temperature for sabha is 96.67
# The temperature for nuuk is 51.8
# The temperature for den helder is 62.85
# The temperature for bubaque is 81.73
# The temperature for rongcheng is 76.24
# The temperature for omboue is 78.17
# The temperature for porbandar is 82.2
# The temperature for homer is 50.31
# The temperature for luganville is 78.8

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Verify length of arrays
print(len(cit))
print(len(lat))
print(len(lng))
print(len(temp))
print(len(humid))
print(len(MaxT))
print(len(cloud))
print(len(wind))
print(len(country))
print(len(date))
# Out:
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558
# 558

# %%
weatherdict = {
        "City": cit,
        "Lat": lat,
        "Lng": lng,
        "Temp": temp,
        "Humidity": humid,
        "Max Temp": MaxT,
        "Cloudiness": cloud,
        "Wind Speed": wind,
        "Country": country,
        "Date": date
}

# %%
weather_data = pd.DataFrame(weatherdict)
weather_data.head()
# Out:
#            City    Lat     Lng   Temp  Humidity  Max Temp  Cloudiness  \
# 0      Savelugu   9.62   -0.83  74.59        87     74.59         100
# 1  Forsytheganj  52.63   29.73  65.98        85     65.98          92
# 2         Pevek  69.70  170.31  37.65        97     37.65         100
# 3     Borshchiv  48.80   26.04  64.00        82     64.00         100
# 4        Mehamn  71.04   27.85  53.60        66     53.60          20
#
#    Wind Speed Country        Date
# 0        7.31      GH  1598371944
# 1        5.97      BY  1598371944
# 2        3.33      RU  1598371944
# 3        4.00      UA  1598371945
# 4        9.17      NO  1598371945

# %%
# Output to CSV file
weather_data.to_csv("weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_data.loc[(weather_data["Humidity"] > 100)]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Temp, Humidity, Max Temp, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# NO CITIES HAVE HUMIDITY > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
Adjlat_df = weather_data.copy()
Adjlat_df['Lat'] = Adjlat_df["Lat"].abs()
Adjlat_df.head()
# Out:
#            City    Lat     Lng   Temp  Humidity  Max Temp  Cloudiness  \
# 0      Savelugu   9.62   -0.83  74.59        87     74.59         100
# 1  Forsytheganj  52.63   29.73  65.98        85     65.98          92
# 2         Pevek  69.70  170.31  37.65        97     37.65         100
# 3     Borshchiv  48.80   26.04  64.00        82     64.00         100
# 4        Mehamn  71.04   27.85  53.60        66     53.60          20
#
#    Wind Speed Country        Date
# 0        7.31      GH  1598371944
# 1        5.97      BY  1598371944
# 2        3.33      RU  1598371944
# 3        4.00      UA  1598371945
# 4        9.17      NO  1598371945

# %%
# Generate scatterplot
Adjlat_df.plot(kind="scatter", x="Lat", y="Temp", grid=True, figsize=(4,4),
              title="Temperature Vs. Latitude")
plt.xlabel("Latitude (North and South)")
plt.ylabel("Current Temperature")
plt.ylim(0, max(Adjlat_df["Temp"])+10)
plt.savefig("Temp.png", format="png")
plt.show()

# %%
# The above code is comparing what currrent temperatures are at various latitudes.  I used the .abs() function to
#   make the data consistent in both the northern and southern hemispheres.  The data shows a distinct decreasing trend as
#   you go further away from the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generate scatterplot
Adjlat_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(4,4),
              title="Humidity Vs. Latitude")
plt.xlabel("Latitude (North and South)")
plt.ylabel("Current Humidity (%)")
plt.ylim(0, max(Adjlat_df["Humidity"])+10)
plt.savefig("Humidity.png", format="png")
plt.show()

# %%
# The above code is comparing what currrent humidity are at various latitudes.  I used the .abs() function to
#   make the data consistent in both the northern and southern hemispheres.  The data appears to show more sporadic humidity
#   readings at lower altitudes, with slightly more consistent readings in the higher latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generate scatterplot
Adjlat_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(4,4),
              title="Cloudiness Vs. Latitude")
plt.xlabel("Latitude (North and South)")
plt.ylabel("Current Cloudiness (%)")
plt.ylim(0, max(Adjlat_df["Cloudiness"])+10)
plt.savefig("Cloudy.png", format="png")
plt.show()

# %%
# The above code is comparing what currrent cloudiness at various latitudes.  I used the .abs() function to
#   make the data consistent in both the northern and southern hemispheres.  The data doesn't appear to have any correlation
#   between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generate scatterplot
Adjlat_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(4,4),
              title="Wind Speed Vs. Latitude")
plt.xlabel("Latitude (North and South)")
plt.ylabel("Current Wind Speed (mph)")
plt.ylim(0, max(Adjlat_df["Wind Speed"])+10)
plt.savefig("Wind.png", format="png")
plt.show()

# %%
# The above code is comparing current wind speeds at various latitudes.  I used the .abs() function to make the data more
#   consistent in both the northern and southern hemispheres.  While there appears to be a slight decreasing trend in wind
#   speed as you go further from the equator, there are more extreme measurements as you get closer to the equator.

# %% [markdown]
# ## Linear Regression

# %%
#Break main dataframe into northern and southern dataframes
north_df = weather_data.loc[(weather_data["Lat"] >= 0)]
south_df = weather_data.loc[(weather_data["Lat"] < 0)]
north_df = north_df.reset_index()
south_df = south_df.reset_index()
#north_df.head()
#south_df.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Calculate linear regression model for north latitude and maximum temperature
Latitude = north_df["Lat"]
TempMax = north_df["Max Temp"]
north_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8), title="Temperature Vs. North Latitude")
plt.xlabel("Degrees North Latitude")
plt.ylabel("Maximum Temperature")
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, TempMax)
regress_values = Latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Latitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.5775606170484364
# y = -0.62x + 94.93

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# The above linear regression model shows a moderate correlation between latitude and maximum temperature.  Between
#   20 and 40 degrees north latitude there appears to be more variability in temperature measurements.

# %%
#Calculate linear regression model for south latitude and maximum temperature
SLatitude = south_df["Lat"]
STempMax = south_df["Max Temp"]
south_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8), title="Temperature Vs. South Latitude")
plt.xlabel("Degrees South Latitude")
plt.ylabel("Maximum Temperature")
(slope, intercept, rvalue, pvalue, stderr) = linregress(SLatitude, STempMax)
regress_values = SLatitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SLatitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.648791008192139
# y = 0.87x + 85.93

# %%
#There appears to be a stronger correlation in the southern hemisphere than the northern hemisphere as far as correlating
#  latitude with maximum temperature.   There also appear to be some more variability in measurements between 0 and 20
#  degrees south latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Calculate linear regression model for north latitude and humidity
Humidity = north_df["Humidity"]
north_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8), title="Humidity Vs. North Latitude")
plt.xlabel("Degrees North Latitude")
plt.ylabel("Humidity (%)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, Humidity)
regress_values = Latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Latitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.02264128822057005
# y = 0.17x + 63.82

# %%
#There appears to be minimal corrrelation between humidity and latitude though the lowest instances in humidity are between
#  10 and 50 degrees north latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Calculate linear regression model for south latitude and humidity
SHumidity = south_df["Humidity"]
south_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8), title="Humidity Vs. South Latitude")
plt.xlabel("Degrees South Latitude")
plt.ylabel("Humidity (%)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(SLatitude, SHumidity)
regress_values = SLatitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SLatitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.021339173955605733
# y = -0.23x + 62.57

# %%
#There appears to be minimal corrrelation between humidity and latitude though the lowest instances in humidity are between
#  10 and 40 degrees south latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Calculate linear regression model for north latitude and cloudiness
Cloudiness = north_df["Cloudiness"]
north_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8), title="Cloudiness Vs. North Latitude")
plt.xlabel("Degrees North Latitude")
plt.ylabel("Cloudiness (%)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, Cloudiness)
regress_values = Latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Latitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.0001611701138238045
# y = -0.02x + 50.91

# %%
# There appears to be no correlation between cloud cover and latitude; measurements are sporadic at every latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Calculate linear regression model for north latitude and cloudiness
SCloudiness = south_df["Cloudiness"]
south_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8), title="Cloudiness Vs. South Latitude")
plt.xlabel("Degrees South Latitude")
plt.ylabel("Cloudiness (%)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(SLatitude, SCloudiness)
regress_values = SLatitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SLatitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.00624723639835114
# y = -0.21x + 34.9

# %%
# There appears to be no correlation between cloud cover and south latitude; measurements are sporadic at every latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Calculate linear regression model for north latitude and wind speed
Windspeed = north_df["Wind Speed"]
north_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8), title="Wind Speed Vs. North Latitude")
plt.xlabel("Degrees North Latitude")
plt.ylabel("Wind Speed (mph)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(Latitude, Windspeed)
regress_values = Latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Latitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.0054535960878257265
# y = -0.02x + 8.28

# %%
# There appears to be little to no correlation between wind speed and latitude; measurements are sporadic at every latitude
#  though the highest wind speeds are between 10 and 50 degrees north latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Calculate linear regression model for south latitude and wind speed
SWindspeed = south_df["Wind Speed"]
south_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8), title="Wind Speed Vs. South Latitude")
plt.xlabel("Degrees South Latitude")
plt.ylabel("Wind Speed (mph)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(SLatitude, SWindspeed)
regress_values = SLatitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(SLatitude,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
print(line_eq)
# Out:
# The r-squared is: 0.014335433110523994
# y = -0.05x + 8.11

# %%
# There appears to be little to no correlation between wind speed and latitude; measurements are sporadic at every latitude
#  though the highest wind speeds are between 20 and 45 degrees south latitude.
